# %% [markdown]
# ### Homework 3 Numpy Arrays and Pandas
#
# 1. Open `cars.csv` in jupyter and look at the data. (Double click `cars.csv` to open in a new tab).
# 2. We are converting each **column** into a numpy array.
# 3. Notice we have text, integer and float data.
# 4. Take care not to overwrite your starter code.

# %%
# !pip3 show numpy

# !pip3 install pandas
# Out:
# Name: numpy
# Version: 2.4.1
# Summary: Fundamental package for array computing in Python
# Home-page:
# Author: Travis E. Oliphant et al.
# Author-email:
# License:
# Location: C:\Users\Eman0\AppData\Local\Programs\Python\Python311\Lib\site-packages
# Requires:
# Required-by: pandas
# ...
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Starter code. Do NOT modify this cell
import numpy as np
import pandas as pd

# Read in dataset
df = pd.read_csv('cars.csv',delimiter=';')

# Convert each column to an np.array
car = df.Car.to_numpy()
mpg = df.MPG.to_numpy()
cylinders = df.Cylinders.to_numpy()
displacement = df.Displacement.to_numpy()
horsepower = df.Horsepower.to_numpy()
weight = df.Weight.to_numpy()
acceleration = df.Acceleration.to_numpy()
model = df.Model.to_numpy()
origin = df.Origin.to_numpy()

# create an array of headers
headers = np.array(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight','Acceleration', 'Model', 'Origin'])

# %% [markdown]
# 1. (2 pts) What are the numpy datatypes for the `car`,`mpg`, `horsepower` and `origin` arrays? (Hint: Not `type(car)` and use `print()` to print the numpy type.)

# %%
print(car.dtype)
print(mpg.dtype)
print(horsepower.dtype)
print(origin.dtype)
#this is what you meant I think, not the list of numbers. please let me know if I misunderstood.
# Out:
# <U6
# float64
# float64
# bool

# %% [markdown]
# 2. (1 pt) `numpy` is often imported as `np`. What is this action called? Why might you do this?

# %%
#because we need to import things into our code for it to work and two because I think its easier for using that a lot, like so you dont have to type out numpy every time you can just type np.

# %% [markdown]
# 3. (2 pts) Each of the arrays (cars, mpg, cylinders, etc..) has how many dimensions? Show how to find this using code.

# %%
print(car.ndim)
print(mpg.ndim)
print(cylinders.ndim)
print(displacement.ndim)
print(horsepower.ndim)
print(weight.ndim)
print(acceleration.ndim)
print(model.ndim)
print(origin.ndim)
#each of them are just 1D.  ## note to self wait on teacher response to my question
# Out:
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1

# %% [markdown]
# 4. (3 pts) What is the ___ of `horsepower`?
# - sum
# - min
# - max
# - median
# - mode

# %%
#ignore copied here from source file so i dont have to alt tab a bunch 
# >> a.sum()                     Array-wise sum
#>>> a.min()                     Array-wise minimum value 
#>>> b.max(axis=0)               Maximum value of an array row
#>>> b.cumsum(axis=1)            Cumulative sum of the elements
#>>> a.mean()                    Mean
#>>> b.median()                  Median
#>>> a.corrcoef()                Correlation coefficient
#>>> np.std(b)                   Standard deviation
import statistics as stats
#initial thoight, it kept only 
#horsepower.sum(), horsepower.min(), horsepower.max(), horsepower.mean(), np.std(horsepower)
#I tried just doing it flat down but it kept only giving me one at a time even if i had them all so
print(np.sum(horsepower))
print(np.min(horsepower))
print(np.max(horsepower))
print(np.median(horsepower))
print(stats.mode(horsepower)) #had to look up video
# Out:
# 42033.0
# 0.0
# 230.0
# 93.5
# 150.0

# %% [markdown]
# 5. (2 pts) Select the last element in each subarray (do this with one operation.)

# %%
select_more = np.array([[3,2,1],
                      [4,5,6],
                      [7,8,9]])
# returns array([1, 6, 9])

# %%
#select_more[1:,-1]

select_more[0:,-1]
# Out:
# array([1, 6, 9])

# %% [markdown]
# 6. (2 pts) a) what is boolean indexing?
# <br/> b) Use boolean indexing to create an array of `True/False` using `origin` and the value 'US'.

# %%
# Out:
# [False False False]

# %% [markdown]
# 7. (2 pts) Apply your index (from above) to the `car` array. You should now only see cars that are of US origin.

# %% [markdown]
# ### Use numpy or pandas to answer the following questions.

# %% [markdown]
# 8. (3 pts) What is the average horsepower for `Europe` cars? (Hint: create a boolean index of 'US' apply it to horsepower and perform the calculation.)

# %% [markdown]
# 9. (3 pts) On average are Japanese cars more fuel-efficient than US cars? Write a function that can handle this comparison.

# %%
# Out:
# ['US']

# %% [markdown]
# 10. (3 pts) What is the correlation coefficient of `mpg` and `weight`? What is a correlation coefficient? What does the result indicate about the relationship between mpg and weight?

# %% [markdown]
# 11. (2 pts) Create a new pandas dataframe that has the average mpg, weight, and horsepower per country of origin

# %% [markdown]
# Extra credit (2 pts): Write a function to find the deepest level of nested brackets
# <br/>Sample Input: {"a":1,"b":2,"c":{"d":3,"e":4,"f":{"g":5,"h":6}}}
# <br/>Sample Output: There are 3 nested layers
